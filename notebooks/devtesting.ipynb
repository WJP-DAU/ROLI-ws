# %%
import re
import time
import requests
from io import StringIO
import pandas as pd
from bs4 import BeautifulSoup

# %%
url = 'https://www.weerawongcp.com/people-list.php?type=practice&key=&order=name_asc&page=2'

# %%
response = requests.get(url)
response.encoding = response.apparent_encoding
soup = BeautifulSoup(response.text, 'lxml')

# %%
def get_individual_data(object):
    href_attr = object.find('a').get('href')
    full_href = f'https://www.weerawongcp.com/{href_attr}'
    
    r = requests.get(full_href)
    r.encoding = r.apparent_encoding
    s =  BeautifulSoup(r.text, 'lxml')

    full_name = s.find('h1').text.strip()
    print(f'Retrieving information for {full_name}')

    country = 'Thailand'
    title   = 'NA'
    generic_title = 'NA'
    given_name  = 'NA'
    family_name = 'NA'
    gender      = 'NA'
    organization = 'Weerawong, Chinnavat & Partners Ltd.'
    mobile = 'NA'

    contact_object = s.find('h3', string = re.compile('Contact')).find_next_siblings()
    try:
        phone = contact_object[0].text
        phone = re.search(
            r'T: (.*?)(?:$)', phone
        ).group(1).strip()
        phone
    except AttributeError:
        phone = 'Not Found'

    try: 
        email = contact_object[2].find('a').get('href').strip()
        email = re.search(
            r'mailto:(.*)$', email
        ).group(1).strip()
    except AttributeError:
        email = 'Not Found'

    try:
        languages = s.find('h3', string = re.compile('Languages')).find_next_siblings('p')[0].text.strip()
    except AttributeError:
        languages = 'Not Found'

    bio = s.find_all('table')[2].find('tr').find_all('td')[1].text.strip()

    lawyer_entry = {
        "country"         : country,
        "title"           : title,
        "generic_title"   : generic_title,
        "given_name"      : given_name,
        "family_name"     : family_name,
        "full_name"       : full_name,
        "gender"          : gender,
        "email"           : email,
        "languages"       : languages,
        # "position"        : position,
        "organization"    : organization,
        "phone"           : phone,
        "mobile"          : mobile,
        # "practice"        : practice,
        "full_href"       : full_href,
        "bio"             : bio
    }

    time.sleep(1)
    
    return lawyer_entry

# %%
def get_page_data(object):
    table_html = object.find('table', class_ = 'sptb1')
    page_data  = pd.read_html(StringIO(str(table_html)))[0]
    page_data.columns = ['full_name', 'practice', 'position']

    lawyer_data_list = [
        get_individual_data(person) 
        for person in soup.find_all('td', class_ = 'xname')
    ]
    lawyer_data = pd.DataFrame(lawyer_data_list)

    return [page_data, lawyer_data]

# %%
X = get_page_data(soup)
# Out:
# Retrieving information for Korakod Jittimaporn
# Retrieving information for Masitorn Boonserm
# Retrieving information for Na napat Bootphet
# Retrieving information for Nakarintr Naka
# Retrieving information for Nantanat Hattathammanoon
# Retrieving information for Narisa Aeimamnuay
# Retrieving information for Nattadit Chatmatasit
# Retrieving information for Nattanicha Siamnikorn
# Retrieving information for Natthanun Suksomboon
# Retrieving information for Natthida Pranutnorapal
# Retrieving information for Nicolas Ranza
# Retrieving information for Nitcha Kasetpheutphon
# Retrieving information for Nontachai Hemaratpitak
# Retrieving information for Padej Khamcharoen
# Retrieving information for Palita Lawanrattanakul

# %%
master_data = pd.merge(X[0], X[1], on = 'full_name', how = 'inner')
master_data
# Out:
#                    full_name                         position   practice  \
# 0        Korakod Jittimaporn               Dispute resolution  Associate
# 1          Masitorn Boonserm  Debt and Equity Capital Markets  Associate
# 2          Na napat Bootphet                              NaN  Associate
# 3             Nakarintr Naka     Real estate and construction  Associate
# 4   Nantanat Hattathammanoon               Dispute resolution  Associate
# 5          Narisa Aeimamnuay              Banking and Finance  Associate
# 6       Nattadit Chatmatasit                              NaN  Associate
# 7      Nattanicha Siamnikorn         Corporate and commercial  Associate
# 8       Natthanun Suksomboon  Debt and Equity Capital Markets  Associate
# 9     Natthida Pranutnorapal          Financial Restructuring    Partner
# 10             Nicolas Ranza           Mergers & Acquisitions  Associate
# 11     Nitcha Kasetpheutphon               Dispute resolution  Associate
# 12    Nontachai Hemaratpitak           Mergers & Acquisitions  Associate
# 13         Padej Khamcharoen              Banking and Finance  Associate
# 14    Palita Lawanrattanakul         Corporate and commercial  Associate
#
#      country title generic_title given_name family_name gender  \
# 0   Thailand    NA            NA         NA          NA     NA
# 1   Thailand    NA            NA         NA          NA     NA
# 2   Thailand    NA            NA         NA          NA     NA
# 3   Thailand    NA            NA         NA          NA     NA
# 4   Thailand    NA            NA         NA          NA     NA
# 5   Thailand    NA            NA         NA          NA     NA
# 6   Thailand    NA            NA         NA          NA     NA
# 7   Thailand    NA            NA         NA          NA     NA
# 8   Thailand    NA            NA         NA          NA     NA
# 9   Thailand    NA            NA         NA          NA     NA
# 10  Thailand    NA            NA         NA          NA     NA
# 11  Thailand    NA            NA         NA          NA     NA
# 12  Thailand    NA            NA         NA          NA     NA
# 13  Thailand    NA            NA         NA          NA     NA
# 14  Thailand    NA            NA         NA          NA     NA
#
#                            email                languages  \
# 0      korakod.j@weerawongcp.com            Thai, English
# 1     masitorn.b@weerawongcp.com            Thai, English
# 2      nanapat.b@weerawongcp.com  Thai, English, Mandarin
# 3    nakarintr.n@weerawongcp.com            Thai, English
# 4     nantanat.h@weerawongcp.com            Thai, English
# 5       narisa.a@weerawongcp.com            Thai, English
# 6     nattadit.c@weerawongcp.com            Thai, English
# 7   nattanicha.s@weerawongcp.com            Thai, English
# 8    natthanun.s@weerawongcp.com            English, Thai
# 9     natthida.p@weerawongcp.com            Thai, English
# 10     nicolas.r@weerawongcp.com            Thai, English
# 11      nitcha.k@weerawongcp.com            Thai, English
# 12   nontachai.h@weerawongcp.com            Thai, English
# 13       padej.k@weerawongcp.com            Thai, English
# 14      palita.l@weerawongcp.com            Thai, English
#
#                             organization            phone mobile  \
